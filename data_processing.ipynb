# %%
#
import pandas as pd
df_Industry = pd.read_csv(r"/home/anle/Data-mining-global-co2-emissions/Raw_data/API_NV.IND.TOTL.ZS_DS2_en_csv_v2_1237963.csv")

# %%
df_Industry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   2000            228 non-null    float64
#  5   2001            228 non-null    float64
#  6   2002            230 non-null    float64
#  7   2003            233 non-null    float64
#  8   2004            234 non-null    float64
#  9   2005            234 non-null    float64
#  10  2006            238 non-null    float64
#  11  2007            239 non-null    float64
#  12  2008            242 non-null    float64
#  13  2009            243 non-null    float64
#  14  2010            245 non-null    float64
#  15  2011            247 non-null    float64
#  16  2012            249 non-null    float64
# ...

# %%
df_Industry.describe()
# Out:
#              2000        2001        2002        2003        2004        2005  \
# count  228.000000  228.000000  230.000000  233.000000  234.000000  234.000000
# mean    27.382698   26.788727   26.886714   26.785027   27.146119   27.579549
# std     11.366176   10.623120   10.707649   10.816077   11.336721   12.223591
# min      4.247151    4.186181    3.243096    4.149037    5.496810    5.251319
# 25%     21.121440   20.894219   20.611314   20.506338   20.482852   20.387102
# 50%     25.689644   25.413103   25.417558   25.309872   25.591847   25.919553
# 75%     32.400025   30.911518   30.703453   30.777971   31.762373   32.230524
# max     84.795979   77.419578   74.157856   70.893813   76.642514   80.974294
#
#              2006        2007        2008        2009  ...        2014  \
# count  238.000000  239.000000  242.000000  243.000000  ...  251.000000
# mean    28.523236   28.332073   28.795663   26.790242  ...   26.346294
# ...

# %%
df_Industry.isna().sum()
# Out:
# Country Name       0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 2000              38
# 2001              38
# 2002              36
# 2003              33
# 2004              32
# 2005              32
# 2006              28
# 2007              27
# 2008              24
# 2009              23
# 2010              21
# 2011              19
# 2012              17
# 2013              15
# 2014              15
# 2015              15
# 2016              16
# 2017              16
# 2018              17
# 2019              17
# 2020              19
# 2021              20
# 2022              22
# 2023              32
# dtype: int64

# %%
df_Industry['Country Name'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df_hdi = pd.read_excel(r"/home/anle/Data-mining-global-co2-emissions/Raw_data/hdr-data.xlsx")
df_hdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4484 entries, 0 to 4483
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   countryIsoCode  4484 non-null   object
#  1   country         4484 non-null   object
#  2   indexCode       4484 non-null   object
#  3   index           4484 non-null   object
#  4   dimension       0 non-null      float64
#  5   indicatorCode   4484 non-null   object
#  6   indicator       4484 non-null   object
#  7   year            4484 non-null   int64
#  8   value           4484 non-null   float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 315.4+ KB

# %%
df_hdi.describe()
# Out:
#        dimension         year        value
# count        0.0  4484.000000  4484.000000
# mean         NaN  2011.739741     0.701806
# std          NaN     6.857741     0.159693
# min          NaN  2000.000000     0.266000
# 25%          NaN  2006.000000     0.580750
# 50%          NaN  2012.000000     0.723000
# 75%          NaN  2018.000000     0.828000
# max          NaN  2023.000000     0.972000

# %%
df_hdi.isna().sum()
# Out:
# countryIsoCode       0
# country              0
# indexCode            0
# index                0
# dimension         4484
# indicatorCode        0
# indicator            0
# year                 0
# value                0
# dtype: int64

# %%
df_deforest = pd.read_csv(
    r"/home/anle/Data-mining-global-co2-emissions/Raw_data/treecover_loss__ha.csv",
    encoding="cp1252"
)
df_name = pd.read_csv(r"/home/anle/Data-mining-global-co2-emissions/Raw_data/iso_metadata.csv")
df_deforest = pd.merge(df_deforest,df_name, on="iso", how="left")
cols = df_deforest.columns.tolist()

new_order = ['iso', 'name'] + [col for col in cols if col not in ['iso', 'name']]
df_deforest = df_deforest[new_order]

# %%
df_deforest.to_csv(r"/home/anle/Data-mining-global-co2-emissions/Raw_data/treecover_loss_ha_final.csv", index=False)

# %%
df_deforest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4776 entries, 0 to 4775
# Data columns (total 5 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   iso                                                                    4776 non-null   object
#  1   name                                                                   4654 non-null   object
#  2   umd_tree_cover_loss__year                                              4776 non-null   int64
#  3   umd_tree_cover_loss__ha (Di?n tích r?ng b? m?t - ha)                   4776 non-null   float64
#  4   gfw_gross_emissions_co2e_all_gases__Mg (phát th?i khí nhà kính - t?n)  4776 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 186.7+ KB

# %%
df_deforest.describe()
# Out:
#        umd_tree_cover_loss__year  \
# count                4776.000000
# mean                 2012.355946
# std                     6.925828
# min                  2001.000000
# 25%                  2006.000000
# 50%                  2012.000000
# 75%                  2018.000000
# max                  2024.000000
#
#        umd_tree_cover_loss__ha (Di?n tích r?ng b? m?t - ha)  \
# count                                       4.776000e+03
# mean                                        1.083155e+05
# std                                         4.584456e+05
# min                                         0.000000e+00
# 25%                                         8.583430e+01
# 50%                                         3.688982e+03
# 75%                                         4.085278e+04
# max                                         8.570166e+06
#
#        gfw_gross_emissions_co2e_all_gases__Mg (phát th?i khí nhà kính - t?n)
# count                                       4.776000e+03
# ...

# %%
df_deforest.isna().sum()
# Out:
# iso                                                                        0
# name                                                                     122
# umd_tree_cover_loss__year                                                  0
# umd_tree_cover_loss__ha (Di?n tích r?ng b? m?t - ha)                       0
# gfw_gross_emissions_co2e_all_gases__Mg (phát th?i khí nhà kính - t?n)      0
# dtype: int64
